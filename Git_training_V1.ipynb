# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid')
pd.set_option('display.max_columns', None)
#import fILE              
DATA_TRX = Path('D:\Learning\Python\Training Sesi 3\studi_kasus_eda_penjualan.xlsx') 
assert DATA_TRX.exists(), 'File Not Found' 
print('Found!') 
#Read File
rf = pd.read_excel(
    DATA_TRX,
    sheet_name='Data Penjualan'
)
rf.head()
print('Jumlah kolum: ', rf.shape[0])
print('Jumlah Kolom: ', rf.shape[1])
print('Nama Kolom: ')
print(rf.columns.tolist())
# # Melihat Type Data
rf.info()
# # Melihat Nilai rata-rata
rf.describe()
# #EDA
# #jumlah nilai Kosong
rf.isna().sum().to_frame('jumlah_kosong')
# #Jumlah Nilai Duplicate
print('Jumlah kolum Duplikat', 
     rf.duplicated().sum(),
     rf[rf.duplicated(keep=False)].sort_values('id_transaksi'))
# Out:
# Found!
# Jumlah Baris:  151
# Jumlah Kolom:  10
# Nama Kolom:
# ['id_transaksi', 'tanggal', 'kota', 'kategori', 'produk', 'jumlah', 'harga_satuan', 'diskon_persen', 'metode_pembayaran', 'rating']
# <class 'pandas.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_transaksi       151 non-null    str
#  1   tanggal            151 non-null    datetime64[us]
#  2   kota               151 non-null    str
#  3   kategori           151 non-null    str
#  4   produk             151 non-null    str
#  5   jumlah             151 non-null    int64
#  6   harga_satuan       151 non-null    int64
#  7   diskon_persen      151 non-null    int64
#  8   metode_pembayaran  151 non-null    str
#  9   rating             148 non-null    float64
# dtypes: datetime64[us](1), float64(1), int64(3), str(5)
# memory usage: 17.2 KB
# Jumlah Baris Duplikat 1     id_transaksi    tanggal      kota kategori       produk  jumlah  \
# 39      TRX-0040 2026-02-13  Makassar  Minuman  Air Mineral       1
# 150     TRX-0040 2026-02-13  Makassar  Minuman  Air Mineral       1
#
#      harga_satuan  diskon_persen metode_pembayaran  rating
# 39           6000             10             Tunai     4.6
# 150          6000             10             Tunai     4.6
